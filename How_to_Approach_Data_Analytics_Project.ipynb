# %% [markdown]
# <div style="width: 100%; text-align: center;">
#     <h1>📊 Types of Approaches in Data Analytics</h1>
# </div>

# %% [markdown]
# ## 🔍 1. Descriptive Analytics
# **Purpose**: Understand what happened in the past
# **Tools/Techniques**:
# - Summary statistics (mean, median, count)
# - Data visualization (charts, graphs)
# - Dashboards
# **Example**: Monthly sales report, website traffic trends
#
# ---
#
# ## 🤔 2. Diagnostic Analytics
# **Purpose**: Understand *why* something happened
# **Tools/Techniques**:
# - Drill-down, data mining
# - Correlation analysis
# - Root cause analysis
# **Example**: Why did sales drop in Q3?
#
# ---
#
# ## 🔮 3. Predictive Analytics
# **Purpose**: Predict future outcomes based on past data
# **Tools/Techniques**:
# - Machine Learning (Regression, Classification)
# - Time Series Forecasting
# **Example**: Predicting customer churn or sales for next quarter
#
# ---
#
# ## 🧭 4. Prescriptive Analytics
# **Purpose**: Suggest actions based on predictions and outcomes
# **Tools/Techniques**:
# - Optimization models
# - Decision trees
# - Simulations
# **Example**: Recommending optimal inventory levels or marketing strategies
#
# ---
#
# ## 🧠 5. Cognitive Analytics (Advanced)
# **Purpose**: Use AI to mimic human reasoning for complex decision-making
# **Tools/Techniques**:
# - Natural Language Processing (NLP)
# - Deep Learning
# **Example**: Chatbots, fraud detection systems, customer sentiment analysis
#
# ---
#
# ## 🔁 Summary Table
#
# | Approach Type         | Goal                      | Example                                 |
# |:-----------------------|:---------------------------|:------------------------------------------|
# | Descriptive Analytics | What happened?            | Monthly revenue trends                   |
# | Diagnostic Analytics  | Why did it happen?        | Sales drop due to fewer repeat buyers    |
# | Predictive Analytics  | What will happen?         | Predict next month’s sales               |
# | Prescriptive Analytics| What should we do?        | Recommend discount strategies            |
# | Cognitive Analytics   | Learn & adapt like humans | Personalized shopping assistants         |
#
# ---

# %% [markdown]
# <div style="width: 100%; text-align: center;">
#     <h1>🧠 Data Analytics Project Approach</h1>
# </div>

# %% [markdown]
# ## 1. 🧩 Understand the Problem Statement
# - **Ask questions**: What is the business goal? Who is the audience?
# - **Example**: "Why have customer purchases dropped in the last 3 months?"
#
# ---
#
# ## 2. 📥 Data Collection
# Gather relevant data from:
# - Databases (via SQL)
# - Excel files, CSVs
# - APIs, web scraping
#
# Understand:
# - Data source limitations
# - Data frequency
# - Data accuracy
#
# ---
#
# ## 3. 🧼 Data Cleaning (Preprocessing)
# - Handle missing values (drop, fill, interpolate)
# - Remove duplicates, fix data types
# - Standardize column names, formats, units
#
# **Tools**: `pandas`, Excel, Power Query
#
# ---
#
# ## 4. 📊 Exploratory Data Analysis (EDA)
# - Use descriptive statistics: mean, median, std, etc.
# - Plot histograms, boxplots, scatterplots, correlation heatmaps
# - Ask:
#   - Are there outliers?
#   - Any seasonal trends or anomalies?
#
# ---
#
# ## 5. ❓ Hypothesis Generation
# - Form assumptions based on observed trends
#   e.g., *“Revenue dropped due to a decline in repeat customers”*
# - Validate or reject hypotheses through deeper analysis
#
# ---
#
# ## 6. 📈 Data Modeling / Insight Generation
# - Apply statistical methods (correlation, regression)
# - Group data for comparative analysis (by region, time, product)
# - Segment users/customers if needed
#
# ---
#
# ## 7. 📌 Visualization
# - Create dashboards using:
#   - Power BI
#   - Tableau
#   - Python libraries: `matplotlib`, `seaborn`
# - Visuals should be:
#   - Clear and relevant
#   - Free from clutter
#
# ---
#
# ## 8. 📑 Reporting & Recommendations
# - Summarize key insights and KPIs
# - Recommend **actions** based on data, not just observations
# - Use **business-friendly** language
#
# ---
#
# ## 9. 🚀 Delivery
# - Prepare a concise report or presentation (PDF, PPT, or dashboard)
# - Tailor the delivery for your audience (executives, technical teams, etc.)
#
# ---
#
# ## ✍️ Example Scenario: E-commerce Sales Drop
#
# | Step         | What You Do                                            |
# |--------------|--------------------------------------------------------|
# | Understand   | Sales down? Which products? Which time?               |
# | Collect      | Get last 12 months' sales data                         |
# | Clean        | Handle null values in "price" column                   |
# | Explore      | Plot sales trend per month                             |
# | Hypothesize  | Maybe ad spend dropped? Customer churn?                |
# | Analyze      | Correlate ad budget and sales                          |
# | Visualize    | Line graph: sales vs time; bar chart: sales by region |
# | Report       | "Sales dropped 25% due to reduced marketing & fewer returning users" |
#
# ---

# %% [markdown]
# <div style="width: 100%; text-align: center;">
#     <h1>📊 KPI (Key Performance Indicator)</h1>
# </div>

# %% [markdown]
# ## 📌 In Simple Terms:
# **KPIs help you track progress toward your goals.**
#
# ## 💡 Examples of KPIs (based on domain):
#
# ### 📦 Sales
# - Monthly revenue
# - Conversion rate
# - Customer acquisition cost (CAC)
#
# ### 🛍️ E-commerce
# - Cart abandonment rate
# - Repeat customer rate
# - Average order value (AOV)
#
# ### 📈 Marketing
# - Click-through rate (CTR)
# - Return on Ad Spend (ROAS)
# - Website traffic growth
#
# ### 👨‍🏫 Education
# - Student attendance rate
# - Graduation rate
# - Course completion rate
#
# ---
#
# ## ✅ A Good KPI Should Be:
#
# Follow the **SMART** rule:
#
# - **Specific**: Tied to a clear goal
# - **Measurable**: Can be tracked with data
# - **Achievable**: Realistic
# - **Relevant**: Aligned with business strategy
# - **Time-bound**: Tracked over time (weekly, monthly, etc.)
#
# ---
#
# ## 📊 Example in a Data Analytics Project
#
# **Project**: Analyze customer retention
# **Goal**: Improve customer retention by 10%
# **KPI**:
# ```math
# Retention Rate = (Returning Customers / Total Customers) × 100
